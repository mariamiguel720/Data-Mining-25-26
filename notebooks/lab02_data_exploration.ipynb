# %% [markdown]
# # Lab 02: Data Exploration

# %% [markdown]
# Summary:
#
# 1. Data Exploration and initial analysis:
#     - Loading the data.
#     - Inspecting data shape, column names, and data types, variable types.
#     - Viewing basic descriptive statistics and unique values.
#     - Subsetting data by rows and columns, and conditional selection.
#
# 2. Data Quality Checks:
#     - Identifying **missing values**.
#     - Checking and correcting **data types**.
#     - Detecting and handling **duplicate records**.
#
# 4. Data Aggregation and Operations:
#     - Summing and aggregating data by columns and rows.
#     - Discussing the appropriateness of different operations.
#
# 5. Visual Exploration:
#     - Plotting univariate distributions (histograms and box plots) for numeric variables.
#     - Using matplotlib and seaborn for data visualization.
#
# 7. Optional Exercise:
#     - Applying the same analysis steps to the project dataset.

# %%
# Remember: library imports are ALWAYS at the top of the script, no exceptions!
import sqlite3
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from math import ceil

# for better resolution plots
# %config InlineBackend.figure_format = 'retina' # optionally, you can change 'svg' to 'retina'

#o svg consegue ampliar infinitamente os gráficos sem perder qualidade mas às vezes é mais lento 
#por isso agora usamos retina

# Seeting seaborn style
sns.set()

# %% [markdown]
# # Context
# The data we will be using through the pratical classes comes from a small relational database whose schema can be seen below:
# ![alt text](../figures/schema.png "Relation database schema")

# %% [markdown]
# # Reading the Data

# %%
# path to database
my_path = os.path.join("..", "data", "datamining.db")

# connect to the database
conn = sqlite3.connect(my_path)

# the query
query = """
select
    age, 
    income, 
    frq, 
    rcn, 
    mnt, 
    clothes, 
    kitchen, 
    small_appliances, 
    toys, 
    house_keeping,
    dependents, 
    per_net_purchase,
    g.gender, 
    e.education, 
    m.status, 
    r.description
from customers as c
    join genders as g on g.id = c.gender_id
    join education_levels as e on e.id = c.education_id
    join marital_status as m on m.id = c.marital_status_id
    join recommendations as r on r.id = c.recommendation_id
order by c.id;
"""

df = pd.read_sql_query(query, conn)

# %% [markdown]
# # Metadata
# - *id* - The unique identifier of the customer
# - *age* - The year of birht of the customer
# - *income* - The income of the customer
# - *frq* - Frequency: number of purchases made by the customer
# - *rcn* - Recency: number of days since last customer purchase
# - *mnt* - Monetary: amount of € spent by the customer in purchases
# - *clothes* - Number of clothes items purchased by the customer
# - *kitchen* - Number of kitchen items purchased by the customer
# - *small_appliances* - Number of small_appliances items purchased by the customer
# - *toys* - Number of toys items purchased by the customer
# - *house_keeping* - Number of house_keeping items purchased by the customer
# - *dependents* - Binary. Whether or not the customer has dependents
# - *per_net_purchase* - Percentage of purchases made online
# - *education* - Education level of the customer
# - *status* - Marital status of the customer
# - *gender* - Gender of the customer
# - *description* - Last customer's recommendation description

# %%
#Atenção: por exemplo a variável age não nos dá a idade dos clientes mas sim o ano em que estes nasceram
# a variável "dependents" é binária ou seja diz-nos se o cliente tem dependência (1) ou não (0)

# %% [markdown]
# # Initial Analysis
#
# Pandas user guide: https://pandas.pydata.org/pandas-docs/stable/user_guide/index.html
#
# Pandas 10 min tutorial: https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html

# %%
df.head()

#por defeito dá-nos as 5 primeiras linhas da nossa tabela se quisermos ter por exemplo as 10 primeiras pomos df.head(10)
# Out:
#     age  income  frq  rcn   mnt  clothes  kitchen  small_appliances  toys  \
# 0  1946   90782   33   66  1402       37        5                44    10
# 1  1936  113023   32    6  1537       55        1                38     4
# 2  1990   28344   11   69    44       32       19                24     1
# 3  1955   93571   26   10   888       60       10                19     6
# 4  1955   91852   31   26  1138       59        5                28     4
#
#    house_keeping dependents  per_net_purchase gender   education    status  \
# 0              3          0                19      M  Graduation  Together
# 1              2          0                 9      F         PhD  Divorced
# 2             24          1                59      M  Graduation   Married
# 3              5          1                35      F      Master
# 4              4          1                34      F  Graduation  Together
#
#        description
# 0  Take my money!!
# 1  Take my money!!
# 2       Kind of OK
# 3         OK nice!
# 4  Take my money!!

# %%
#este código faz o mesmo mas para as últimas 5 linhas
df.tail()
# Out:
#        age  income  frq  rcn   mnt  clothes  kitchen  small_appliances  toys  \
# 8993  1960   94367   28    1   896       68        5                21     3
# 8994  1975   58121   12    6    61       53        6                28     7
# 8995  1986   54292   29   72  1011       41       11                36     1
# 8996  1938  125962   38   75  1668       61        2                25     5
# 8997  1994   26385    9   24    46        5       13                21    46
#
#       house_keeping dependents  per_net_purchase gender   education    status  \
# 8993              4          1                55      F   1st Cycle    Single
# 8994              6          1                71      M   2nd Cycle    Single
# 8995             11          0                31      M  Graduation  Together
# 8996              6          1                45      M   2nd Cycle   Married
# 8997             15          1                52      M   1st Cycle    Single
#
#           description
# 8993  Take my money!!
# 8994           Meh...
# 8995  Take my money!!
# 8996  Take my money!!
# 8997       Kind of OK

# %%
df.tail().T
# Out:
#                              8993       8994             8995  \
# age                          1960       1975             1986
# income                      94367      58121            54292
# frq                            28         12               29
# rcn                             1          6               72
# mnt                           896         61             1011
# clothes                        68         53               41
# kitchen                         5          6               11
# small_appliances               21         28               36
# toys                            3          7                1
# house_keeping                   4          6               11
# dependents                      1          1                0
# per_net_purchase               55         71               31
# gender                          F          M                M
# education               1st Cycle  2nd Cycle       Graduation
# status                     Single     Single         Together
# description       Take my money!!     Meh...  Take my money!!
#
#                              8996        8997
# age                          1938        1994
# income                     125962       26385
# frq                            38           9
# rcn                            75          24
# mnt                          1668          46
# clothes                        61           5
# kitchen                         2          13
# small_appliances               25          21
# toys                            5          46
# house_keeping                   6          15
# dependents                      1           1
# per_net_purchase               45          52
# gender                          M           M
# education               2nd Cycle   1st Cycle
# status                    Married      Single
# description       Take my money!!  Kind of OK

# %% [markdown]
# ## What are some characteristics of our data?

# %% [markdown]
# We can use the `.shape` method to see how much data we have.
#
# It returns a tuple with (nrows, ncols).

# %%
# Check the shape
df.shape
# Out:
# (8998, 16)

# %%
# How to get the names of the columns of the data?
df.columns
# Out:
# Index(['age', 'income', 'frq', 'rcn', 'mnt', 'clothes', 'kitchen',
#        'small_appliances', 'toys', 'house_keeping', 'dependents',
#        'per_net_purchase', 'gender', 'education', 'status', 'description'],
#       dtype='object')

# %% [markdown]
# We can use the `.info()` method to get some information about the dataset we have.

# %%
# Check the info
df.info()
#os non-null values diz-nos que não temos valores nulos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8998 entries, 0 to 8997
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               8998 non-null   int64
#  1   income            8998 non-null   object
#  2   frq               8998 non-null   int64
#  3   rcn               8998 non-null   int64
#  4   mnt               8998 non-null   int64
#  5   clothes           8998 non-null   int64
#  6   kitchen           8998 non-null   int64
#  7   small_appliances  8998 non-null   int64
#  8   toys              8998 non-null   int64
#  9   house_keeping     8998 non-null   int64
#  10  dependents        8998 non-null   object
#  11  per_net_purchase  8998 non-null   int64
#  12  gender            8998 non-null   object
#  13  education         8998 non-null   object
#  14  status            8998 non-null   object
#  15  description       8998 non-null   object
# dtypes: int64(10), object(6)
# memory usage: 1.1+ MB

# %% [markdown]
# What do these mean?
#
# - Non-Null Count
# - Dtype
#     - object
#     - float64
#     - bool

# %% [markdown]
# Let's look at datatypes more closely.
#
# Do their values look correct?
#
# *Hint* compare the dtypes with the provided metadata.

# %%
# Check data types
df.dtypes
# Out:
# age                  int64
# income              object
# frq                  int64
# rcn                  int64
# mnt                  int64
# clothes              int64
# kitchen              int64
# small_appliances     int64
# toys                 int64
# house_keeping        int64
# dependents          object
# per_net_purchase     int64
# gender              object
# education           object
# status              object
# description         object
# dtype: object

# %%
#Agora queremos ver que variáveis têm o "type" errado
#income - está mal pq nao faz sentido ser considerado um "object" income é uma numérica
#dependents -  tb está mal pq pela metabase sabemos que esta é uma variável binária, ou seja, pelo
# resumo da stora percebemos que esta é um Bool

# %% [markdown]
# We can use the `.describe()` method to calculate the basic descriptive statistics of our data.

# %%
# Check the descriptive statics
df.describe().round(2) #usamos o round só para não ter tantos zeros e ser menos confuso a ver
# Out:
#            age      frq      rcn      mnt  clothes  kitchen  small_appliances  \
# count  8998.00  8998.00  8998.00  8998.00  8998.00  8998.00           8998.00
# mean   1966.06    19.85    62.47   622.16    50.45     7.04             28.52
# std      17.30    10.90    69.76   646.77    23.42     7.85             12.59
# min    1936.00     3.00     0.00     6.00     1.00     0.00              1.00
# 25%    1951.00    10.00    26.00    63.00    33.00     2.00             19.00
# 50%    1966.00    17.00    53.00   383.00    51.00     4.00             28.00
# 75%    1981.00    28.00    79.00  1076.00    69.00    10.00             37.00
# max    1996.00    59.00   549.00  3052.00    99.00    75.00             74.00
#
#           toys  house_keeping  per_net_purchase
# count  8998.00        8998.00           8998.00
# mean      7.04           6.93             42.43
# std       7.92           7.88             18.50
# min       0.00           0.00              4.00
# 25%       2.00           2.00             28.00
# 50%       4.00           4.00             45.00
# 75%      10.00           9.00             57.00
# max      62.00          77.00             88.00

# %%
# CONCLUSÕES DA TABELA ANTERIOR
#neste caso o nosso valor máximo vai ser o nosso cliente mais novo e o valor mais baixo o cliente mais velho

#per_net_purchase o valor minimo é 4 ou seja, não temos clientes que só compram na loja fisica,
#temos sempre clientes que compram online

#o mínimo de mmnt é 6 ou seja a pessoa que gastou menos na loja gastou 6€
#se a frq fosse 0 (ninguem foi à loja) mas ainda assim tivessemos um mnt, ou seja, 
#um valor minimo de compra de 3€ saberíamos que as compras teriam de ter sido feitas online

# %% [markdown]
# By default `.describe()` only considers numeric features.

# %%
## Modify the .describe() method to check object types

df.describe(include = 'object')
#aqui podemos ver a "descrição" das nossas variáveis que são consideradas objetos
#no enatnto já sabemos que temmos algumas variáveis mal alocadas nesta categoria e por isso temos 
#valores em branco na tabela
# Out:
#        income  dependents gender   education   status description
# count    8998        8998   8998        8998     8998        8998
# unique   8525           3      2           7        7           5
# top                     1      M  Graduation  Married    OK nice!
# freq       46        6164   5784        4429     3273        3434

# %%
## Modify the .describe() method to check all data types
df.describe(include = 'all')
# Out:
#                 age income          frq          rcn          mnt  \
# count   8998.000000   8998  8998.000000  8998.000000  8998.000000
# unique          NaN   8525          NaN          NaN          NaN
# top             NaN                 NaN          NaN          NaN
# freq            NaN     46          NaN          NaN          NaN
# mean    1966.059680    NaN    19.848077    62.469771   622.162814
# std       17.296552    NaN    10.903435    69.761802   646.768205
# min     1936.000000    NaN     3.000000     0.000000     6.000000
# 25%     1951.000000    NaN    10.000000    26.000000    63.000000
# 50%     1966.000000    NaN    17.000000    53.000000   383.000000
# 75%     1981.000000    NaN    28.000000    79.000000  1076.000000
# max     1996.000000    NaN    59.000000   549.000000  3052.000000
#
#             clothes      kitchen  small_appliances         toys  \
# count   8998.000000  8998.000000       8998.000000  8998.000000
# unique          NaN          NaN               NaN          NaN
# top             NaN          NaN               NaN          NaN
# freq            NaN          NaN               NaN          NaN
# mean      50.446655     7.039675         28.524116     7.036897
# std       23.422249     7.848139         12.586437     7.924422
# min        1.000000     0.000000          1.000000     0.000000
# 25%       33.000000     2.000000         19.000000     2.000000
# 50%       51.000000     4.000000         28.000000     4.000000
# 75%       69.000000    10.000000         37.000000    10.000000
# max       99.000000    75.000000         74.000000    62.000000
#
#         house_keeping  dependents  per_net_purchase gender   education  \
# count     8998.000000      8998.0       8998.000000   8998        8998
# unique            NaN         3.0               NaN      2           7
# top               NaN         1.0               NaN      M  Graduation
# freq              NaN      6164.0               NaN   5784        4429
# mean         6.929984         NaN         42.428984    NaN         NaN
# std          7.882655         NaN         18.495742    NaN         NaN
# min          0.000000         NaN          4.000000    NaN         NaN
# 25%          2.000000         NaN         28.000000    NaN         NaN
# 50%          4.000000         NaN         45.000000    NaN         NaN
# 75%          9.000000         NaN         57.000000    NaN         NaN
# max         77.000000         NaN         88.000000    NaN         NaN
#
#          status description
# count      8998        8998
# unique        7           5
# top     Married    OK nice!
# freq       3273        3434
# mean        NaN         NaN
# std         NaN         NaN
# min         NaN         NaN
# 25%         NaN         NaN
# 50%         NaN         NaN
# 75%         NaN         NaN
# max         NaN         NaN

# %% [markdown]
# ## Let's do some operations on our data

# %% [markdown]
# ### Taking a subset of data
#
# You can take a subset with fewer columns by giving a **list** of features:

# %%
## Notice that we use two sets of square brackets

df[['age', 'education']] #para vermos que podemos ver apenas duas colunas de uma vez

# %% [markdown]
# You can select a single column of data by providing the name of a single column. This returns a "Series", instead of a DataFrame.

# %%
# How to get the values of one column of data?
# Different ways to access the values of a column
df.age
df.loc[:, 'age'] #diz que queremos todas as linhas da coluna "age"
# Out:
# 0       1946
# 1       1936
# 2       1990
# 3       1955
# 4       1955
#         ...
# 8993    1960
# 8994    1975
# 8995    1986
# 8996    1938
# 8997    1994
# Name: age, Length: 8998, dtype: int64

# %%
df['age']
# Out:
# 0       1946
# 1       1936
# 2       1990
# 3       1955
# 4       1955
#         ...
# 8993    1960
# 8994    1975
# 8995    1986
# 8996    1938
# 8997    1994
# Name: age, Length: 8998, dtype: int64

# %%
## Notice the difference

df[['age']]
# Out:
#        age
# 0     1946
# 1     1936
# 2     1990
# 3     1955
# 4     1955
# ...    ...
# 8993  1960
# 8994  1975
# 8995  1986
# 8996  1938
# 8997  1994
#
# [8998 rows x 1 columns]

# %%
# How to get the unique values of one column of data?

df['education'].unique()
#os dois ultimos valores não fazem sentido pq temos um valor em branco e uma "oldschool", o que isso significa...
# Out:
# array(['Graduation', 'PhD', 'Master', '1st Cycle', '2nd Cycle',
#        'OldSchool', ''], dtype=object)

# %% [markdown]
# #### What about a subset of rows?

# %%
df.loc[[0,1,2,3,4]]
# Out:
#     age  income  frq  rcn   mnt  clothes  kitchen  small_appliances  toys  \
# 0  1946   90782   33   66  1402       37        5                44    10
# 1  1936  113023   32    6  1537       55        1                38     4
# 2  1990   28344   11   69    44       32       19                24     1
# 3  1955   93571   26   10   888       60       10                19     6
# 4  1955   91852   31   26  1138       59        5                28     4
#
#    house_keeping dependents  per_net_purchase gender   education    status  \
# 0              3          0                19      M  Graduation  Together
# 1              2          0                 9      F         PhD  Divorced
# 2             24          1                59      M  Graduation   Married
# 3              5          1                35      F      Master
# 4              4          1                34      F  Graduation  Together
#
#        description
# 0  Take my money!!
# 1  Take my money!!
# 2       Kind of OK
# 3         OK nice!
# 4  Take my money!!

# %%
df.loc[[10,11,12,13,14]]
#chama as linhas 10 até à 14
#mostra-nos que o comando "loc" é muito importante pq nos permite selecionar as linhas ou colunas que queremos
# Out:
#      age income  frq  rcn   mnt  clothes  kitchen  small_appliances  toys  \
# 10  1949  97492   20   93   774       37       16                33     9
# 11  1957  75436   17   32   491       60        4                33     2
# 12  1954  95586   32   54  1407       27        3                39    20
# 13  1979  57997   10   28    81       77        0                21     1
# 14  1982  50289   10  231    20       46        0                33    16
#
#     house_keeping dependents  per_net_purchase gender   education    status  \
# 10              5          0                15      M      Master    Single
# 11              1          1                29      M  Graduation  Together
# 12             11          0                23      F   2nd Cycle     Widow
# 13              0          1                52      M  Graduation   Married
# 14              5          1                70      M         PhD  Together
#
#         description
# 10         OK nice!
# 11         OK nice!
# 12  Take my money!!
# 13           Meh...
# 14           Meh...

# %%
## .loc also works for column subsets

df.loc[[0,1,2,3,4], ['age', 'education']]
# Out:
#     age   education
# 0  1946  Graduation
# 1  1936         PhD
# 2  1990  Graduation
# 3  1955      Master
# 4  1955  Graduation

# %%
## Can you guess what this means?

df.loc[:,:]
# Out:
#        age  income  frq  rcn   mnt  clothes  kitchen  small_appliances  toys  \
# 0     1946   90782   33   66  1402       37        5                44    10
# 1     1936  113023   32    6  1537       55        1                38     4
# 2     1990   28344   11   69    44       32       19                24     1
# 3     1955   93571   26   10   888       60       10                19     6
# 4     1955   91852   31   26  1138       59        5                28     4
# ...    ...     ...  ...  ...   ...      ...      ...               ...   ...
# 8993  1960   94367   28    1   896       68        5                21     3
# 8994  1975   58121   12    6    61       53        6                28     7
# 8995  1986   54292   29   72  1011       41       11                36     1
# 8996  1938  125962   38   75  1668       61        2                25     5
# 8997  1994   26385    9   24    46        5       13                21    46
#
#       house_keeping dependents  per_net_purchase gender   education    status  \
# 0                 3          0                19      M  Graduation  Together
# 1                 2          0                 9      F         PhD  Divorced
# 2                24          1                59      M  Graduation   Married
# 3                 5          1                35      F      Master
# 4                 4          1                34      F  Graduation  Together
# ...             ...        ...               ...    ...         ...       ...
# 8993              4          1                55      F   1st Cycle    Single
# 8994              6          1                71      M   2nd Cycle    Single
# 8995             11          0                31      M  Graduation  Together
# 8996              6          1                45      M   2nd Cycle   Married
# 8997             15          1                52      M   1st Cycle    Single
#
#           description
# 0     Take my money!!
# 1     Take my money!!
# 2          Kind of OK
# 3            OK nice!
# 4     Take my money!!
# ...               ...
# 8993  Take my money!!
# 8994           Meh...
# 8995  Take my money!!
# 8996  Take my money!!
# 8997       Kind of OK
#
# [8998 rows x 16 columns]

# %% [markdown]
# #### What about a subset based on a condition?
#
# I want the customers with Age < 40

# %%
df.loc[df['age'] > (2025-40) ]
# Out:
#        age income  frq  rcn   mnt  clothes  kitchen  small_appliances  toys  \
# 2     1990  28344   11   69    44       32       19                24     1
# 9     1994  23846    8  153    19       18       55                17    10
# 15    1992  20043    5   37    16        6       28                35    28
# 17    1990  26141    8   52    36       19       17                28    23
# 18    1988  40944   10   67    52       30       12                46     9
# ...    ...    ...  ...  ...   ...      ...      ...               ...   ...
# 8973  1993  35322   13    4    71        9       16                11    62
# 8985  1992  32641    9   29    62       12       21                34    31
# 8990  1995  28144   10   41    46       11       40                24    22
# 8995  1986  54292   29   72  1011       41       11                36     1
# 8997  1994  26385    9   24    46        5       13                21    46
#
#       house_keeping dependents  per_net_purchase gender   education    status  \
# 2                24          1                59      M  Graduation   Married
# 9                 1          1                39      F   1st Cycle  Together
# 15                3          0                51      M  Graduation    Single
# 17               12          0                50      M  Graduation  Together
# 18                3          1                60      M   2nd Cycle  Together
# ...             ...        ...               ...    ...         ...       ...
# 8973              2          0                80      M   2nd Cycle    Single
# 8985              2          1                53      M  Graduation    Single
# 8990              2          1                59      M   1st Cycle   Married
# 8995             11          0                31      M  Graduation  Together
# 8997             15          1                52      M   1st Cycle    Single
#
#           description
# 2          Kind of OK
# 9              Meh...
# 15         Kind of OK
# 17             Meh...
# 18             Meh...
# ...               ...
# 8973           Meh...
# 8985           Meh...
# 8990         OK nice!
# 8995  Take my money!!
# 8997       Kind of OK
#
# [1578 rows x 16 columns]

# %%
## Let's break this down

age = 40
birthyear = (2025-age)
birthyear
# Out:
# 1985

# %%
## Let's break this down
df['age']
# Out:
# 0       1946
# 1       1936
# 2       1990
# 3       1955
# 4       1955
#         ...
# 8993    1960
# 8994    1975
# 8995    1986
# 8996    1938
# 8997    1994
# Name: age, Length: 8998, dtype: int64

# %%
## Let's break this down

df['age'] > birthyear
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 8993    False
# 8994    False
# 8995     True
# 8996    False
# 8997     True
# Name: age, Length: 8998, dtype: bool

# %%
## Let's break this down

df.loc[df['age'] > birthyear]
# Out:
#        age income  frq  rcn   mnt  clothes  kitchen  small_appliances  toys  \
# 2     1990  28344   11   69    44       32       19                24     1
# 9     1994  23846    8  153    19       18       55                17    10
# 15    1992  20043    5   37    16        6       28                35    28
# 17    1990  26141    8   52    36       19       17                28    23
# 18    1988  40944   10   67    52       30       12                46     9
# ...    ...    ...  ...  ...   ...      ...      ...               ...   ...
# 8973  1993  35322   13    4    71        9       16                11    62
# 8985  1992  32641    9   29    62       12       21                34    31
# 8990  1995  28144   10   41    46       11       40                24    22
# 8995  1986  54292   29   72  1011       41       11                36     1
# 8997  1994  26385    9   24    46        5       13                21    46
#
#       house_keeping dependents  per_net_purchase gender   education    status  \
# 2                24          1                59      M  Graduation   Married
# 9                 1          1                39      F   1st Cycle  Together
# 15                3          0                51      M  Graduation    Single
# 17               12          0                50      M  Graduation  Together
# 18                3          1                60      M   2nd Cycle  Together
# ...             ...        ...               ...    ...         ...       ...
# 8973              2          0                80      M   2nd Cycle    Single
# 8985              2          1                53      M  Graduation    Single
# 8990              2          1                59      M   1st Cycle   Married
# 8995             11          0                31      M  Graduation  Together
# 8997             15          1                52      M   1st Cycle    Single
#
#           description
# 2          Kind of OK
# 9              Meh...
# 15         Kind of OK
# 17             Meh...
# 18             Meh...
# ...               ...
# 8973           Meh...
# 8985           Meh...
# 8990         OK nice!
# 8995  Take my money!!
# 8997       Kind of OK
#
# [1578 rows x 16 columns]

# %% [markdown]
# ### Aggregating data
#
# We can perform mathematical operations on our data

# %%
df['age'].sum()
# Out:
# np.int64(17690605)

# %%
## Does it make sense to do this?

df.sum(numeric_only=True)
# Out:
# age                 17690605
# frq                   178593
# rcn                   562103
# mnt                  5598221
# clothes               453919
# kitchen                63343
# small_appliances      256660
# toys                   63318
# house_keeping          62356
# per_net_purchase      381776
# dtype: int64

# %%
## Think of other operations to try: 
## Add two columns together: frq and mnt
df['frq'] + df['mnt'] #não faz sentido fazer isto mas faz sentido dividir pq obtemos a média de gasto de cada cliente por visita
## Does this make sense?
df['mnt'] / df['frq']
# Out:
# 0       42.484848
# 1       48.031250
# 2        4.000000
# 3       34.153846
# 4       36.709677
#           ...
# 8993    32.000000
# 8994     5.083333
# 8995    34.862069
# 8996    43.894737
# 8997     5.111111
# Length: 8998, dtype: float64

# %% [markdown]
# You can also do this by row

# %%
## Sum by column

df.sum(numeric_only=True)
# Out:
# age                 17690605
# frq                   178593
# rcn                   562103
# mnt                  5598221
# clothes               453919
# kitchen                63343
# small_appliances      256660
# toys                   63318
# house_keeping          62356
# per_net_purchase      381776
# dtype: int64

# %%
## Sum by row
## Notice the difference

df.sum(numeric_only=True, axis=1) #em cada linha soma todas as colunas, 
#estamos a juntar idade com frequencia e com todas as outras variáveis o que não faz grande sentido
# Out:
# 0       3565
# 1       3620
# 2       2273
# 3       3014
# 4       3284
#         ...
# 8993    3041
# 8994    2225
# 8995    3229
# 8996    3863
# 8997    2225
# Length: 8998, dtype: int64

# %% [markdown]
# Discussion:
#
# Does it make sense to add all the numeric features in one row?

# %% [markdown]
# ## Take a closer look and point out possible problems

# %%
df.describe()
# Out:
#                age          frq          rcn          mnt      clothes  \
# count  8998.000000  8998.000000  8998.000000  8998.000000  8998.000000
# mean   1966.059680    19.848077    62.469771   622.162814    50.446655
# std      17.296552    10.903435    69.761802   646.768205    23.422249
# min    1936.000000     3.000000     0.000000     6.000000     1.000000
# 25%    1951.000000    10.000000    26.000000    63.000000    33.000000
# 50%    1966.000000    17.000000    53.000000   383.000000    51.000000
# 75%    1981.000000    28.000000    79.000000  1076.000000    69.000000
# max    1996.000000    59.000000   549.000000  3052.000000    99.000000
#
#            kitchen  small_appliances         toys  house_keeping  \
# count  8998.000000       8998.000000  8998.000000    8998.000000
# mean      7.039675         28.524116     7.036897       6.929984
# std       7.848139         12.586437     7.924422       7.882655
# min       0.000000          1.000000     0.000000       0.000000
# 25%       2.000000         19.000000     2.000000       2.000000
# 50%       4.000000         28.000000     4.000000       4.000000
# 75%      10.000000         37.000000    10.000000       9.000000
# max      75.000000         74.000000    62.000000      77.000000
#
#        per_net_purchase
# count       8998.000000
# mean          42.428984
# std           18.495742
# min            4.000000
# 25%           28.000000
# 50%           45.000000
# 75%           57.000000
# max           88.000000

# %%
df.describe(include='object')
# Out:
#        income  dependents gender   education   status description
# count    8998        8998   8998        8998     8998        8998
# unique   8525           3      2           7        7           5
# top                     1      M  Graduation  Married    OK nice!
# freq       46        6164   5784        4429     3273        3434

# %%
df.head()
# Out:
#     age  income  frq  rcn   mnt  clothes  kitchen  small_appliances  toys  \
# 0  1946   90782   33   66  1402       37        5                44    10
# 1  1936  113023   32    6  1537       55        1                38     4
# 2  1990   28344   11   69    44       32       19                24     1
# 3  1955   93571   26   10   888       60       10                19     6
# 4  1955   91852   31   26  1138       59        5                28     4
#
#    house_keeping dependents  per_net_purchase gender   education    status  \
# 0              3          0                19      M  Graduation  Together
# 1              2          0                 9      F         PhD  Divorced
# 2             24          1                59      M  Graduation   Married
# 3              5          1                35      F      Master
# 4              4          1                34      F  Graduation  Together
#
#        description
# 0  Take my money!!
# 1  Take my money!!
# 2       Kind of OK
# 3         OK nice!
# 4  Take my money!!

# %% [markdown]
# ### Missing Values
#
# (hint: a missing values in pandas is represented with a NaN value)

# %% [markdown]
# We can use the `.isna()` method to see if we have missing values.

# %%
## .isna() returns True if the value in that cell is missing, and False otherwise.

df.isna()

## Is this helpful?#não ajuda em nada pq temos muitos valores
# Out:
#         age  income    frq    rcn    mnt  clothes  kitchen  small_appliances  \
# 0     False   False  False  False  False    False    False             False
# 1     False   False  False  False  False    False    False             False
# 2     False   False  False  False  False    False    False             False
# 3     False   False  False  False  False    False    False             False
# 4     False   False  False  False  False    False    False             False
# ...     ...     ...    ...    ...    ...      ...      ...               ...
# 8993  False   False  False  False  False    False    False             False
# 8994  False   False  False  False  False    False    False             False
# 8995  False   False  False  False  False    False    False             False
# 8996  False   False  False  False  False    False    False             False
# 8997  False   False  False  False  False    False    False             False
#
#        toys  house_keeping  dependents  per_net_purchase  gender  education  \
# 0     False          False       False             False   False      False
# 1     False          False       False             False   False      False
# 2     False          False       False             False   False      False
# 3     False          False       False             False   False      False
# 4     False          False       False             False   False      False
# ...     ...            ...         ...               ...     ...        ...
# 8993  False          False       False             False   False      False
# 8994  False          False       False             False   False      False
# 8995  False          False       False             False   False      False
# 8996  False          False       False             False   False      False
# 8997  False          False       False             False   False      False
#
#       status  description
# 0      False        False
# 1      False        False
# 2      False        False
# 3      False        False
# 4      False        False
# ...      ...          ...
# 8993   False        False
# 8994   False        False
# 8995   False        False
# 8996   False        False
# 8997   False        False
#
# [8998 rows x 16 columns]

# %%
## .isna() returns True if the value in that cell is missing, and False otherwise.

df.isna().sum()

## What does this mean?
## Is this helpful?
# Out:
# age                 0
# income              0
# frq                 0
# rcn                 0
# mnt                 0
# clothes             0
# kitchen             0
# small_appliances    0
# toys                0
# house_keeping       0
# dependents          0
# per_net_purchase    0
# gender              0
# education           0
# status              0
# description         0
# dtype: int64

# %%
# count of missing values
df.isna().sum()
# Out:
# age                 0
# income              0
# frq                 0
# rcn                 0
# mnt                 0
# clothes             0
# kitchen             0
# small_appliances    0
# toys                0
# house_keeping       0
# dependents          0
# per_net_purchase    0
# gender              0
# education           0
# status              0
# description         0
# dtype: int64

# %%
# replace "" by nans
df.replace("", np.nan, inplace=True) #faz com que os valores em falta passem a ser NaN values
#agora sim já faz sentido somar os NaN values para saber quantos temos

# count of missing values
df.isna().sum()
#verificamos que temos missing values que transformamos em NaN em income, dependents, education, status
# Out:
# /var/folders/s9/nfpy2jls4ps2k_p8lpjz6_yr0000gn/T/ipykernel_9151/2714014414.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace("", np.nan, inplace=True) #faz com que os valores em falta passem a ser NaN values
# age                   0
# income               46
# frq                   0
# rcn                   0
# mnt                   0
# clothes               0
# kitchen               0
# small_appliances      0
# toys                  0
# house_keeping         0
# dependents          282
# per_net_purchase      0
# gender                0
# education            47
# status              177
# description           0
# dtype: int64

# %% [markdown]
# ### Data Types

# %%
# check dataset data types again
df.dtypes
#trocou o income para float mas dependents tb estão em float e nos nao queremos isto queremos boolean
# Out:
# age                   int64
# income              float64
# frq                   int64
# rcn                   int64
# mnt                   int64
# clothes               int64
# kitchen               int64
# small_appliances      int64
# toys                  int64
# house_keeping         int64
# dependents          float64
# per_net_purchase      int64
# gender               object
# education            object
# status               object
# description          object
# dtype: object

# %%
# fix wrong dtypes
df.dependents = df.dependents.astype("boolean")  # converting to "boolean" over "bool" allows preservation of NaNs

# %%
# check descriptive statistics again
df.describe(include="all").T
# Out:
#                    count unique         top  freq          mean           std  \
# age               8998.0    NaN         NaN   NaN    1966.05968     17.296552
# income            8952.0    NaN         NaN   NaN  69963.550827  27591.556226
# frq               8998.0    NaN         NaN   NaN     19.848077     10.903435
# rcn               8998.0    NaN         NaN   NaN     62.469771     69.761802
# mnt               8998.0    NaN         NaN   NaN    622.162814    646.768205
# clothes           8998.0    NaN         NaN   NaN     50.446655     23.422249
# kitchen           8998.0    NaN         NaN   NaN      7.039675      7.848139
# small_appliances  8998.0    NaN         NaN   NaN     28.524116     12.586437
# toys              8998.0    NaN         NaN   NaN      7.036897      7.924422
# house_keeping     8998.0    NaN         NaN   NaN      6.929984      7.882655
# dependents          8716      2        True  6164           NaN           NaN
# per_net_purchase  8998.0    NaN         NaN   NaN     42.428984     18.495742
# gender              8998      2           M  5784           NaN           NaN
# education           8951      6  Graduation  4429           NaN           NaN
# status              8821      6     Married  3273           NaN           NaN
# description         8998      5    OK nice!  3434           NaN           NaN
#
#                       min      25%      50%      75%       max
# age                1936.0   1951.0   1966.0   1981.0    1996.0
# income            10000.0  47741.0  70030.5  92218.0  140628.0
# frq                   3.0     10.0     17.0     28.0      59.0
# rcn                   0.0     26.0     53.0     79.0     549.0
# mnt                   6.0     63.0    383.0   1076.0    3052.0
# clothes               1.0     33.0     51.0     69.0      99.0
# kitchen               0.0      2.0      4.0     10.0      75.0
# small_appliances      1.0     19.0     28.0     37.0      74.0
# toys                  0.0      2.0      4.0     10.0      62.0
# house_keeping         0.0      2.0      4.0      9.0      77.0
# dependents            NaN      NaN      NaN      NaN       NaN
# per_net_purchase      4.0     28.0     45.0     57.0      88.0
# gender                NaN      NaN      NaN      NaN       NaN
# education             NaN      NaN      NaN      NaN       NaN
# status                NaN      NaN      NaN      NaN       NaN
# description           NaN      NaN      NaN      NaN       NaN

# %% [markdown]
# ### Duplicates

# %%
# duplicated observations
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# *What would it look like if we had duplicates?*
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.duplicated.html
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html

# %%
df_dupes = pd.DataFrame({
     'brand': ['Yum Yum', 'Yum Yum', 'Indomie', 'Indomie', 'Indomie'],
     'style': ['cup', 'cup', 'cup', 'pack', 'pack'],
     'rating': [4, 4, 3.5, 15, 5]
})

df_dupes
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %%
# duplicated observations
df_dupes.duplicated().sum()
# Out:
# np.int64(1)

# %%
df_dupes.drop_duplicates()
df_dupes
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %%
df_dupes2 = df_dupes.drop_duplicates()
df_dupes2 #agora sim os valores duplicados desapareceram
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %%
# df_dupes.drop_duplicates(i) nao percebi o que ela escreveu

# %% [markdown]
# ## Take a closer look and point out possible problems:
#
# - Duplicates?
# - Data types?
# - Missing values?
# - Strange values?
# - Descriptive statistics?

# %% [markdown]
# # Visual Exploration
#
# Matplotlib tutorials: https://matplotlib.org/stable/tutorials/index.html
#
# Matplotlib gallery: https://matplotlib.org/stable/gallery/index.html
#
# Seaborn tutorials: https://seaborn.pydata.org/tutorial.html
#
#
# Seaborn gallery: https://seaborn.pydata.org/examples/index.html
#
# ### Matplotlib vs Seaborn:
#
# **Matplotlib** - lower level. allows to fully customize the plot appearance
#
# **Seaborn** - higher level. Complex off-the-shelf plots with one line. Matplotlib on steroids

# %%
# Define metric and non-metric features. Why?
non_metric_features = ["education", "status", "gender", "dependents", "description"]
metric_features = df.columns.drop(non_metric_features).to_list()

# %% [markdown]
# ## Pyplot-style vs Object-Oriented-style
# - Explicitly create figures and axes, and call methods on them (the "object-oriented (OO) style").
# - Rely on pyplot to automatically create and manage the figures and axes, and use pyplot functions for plotting.
#
# More details: https://matplotlib.org/matplotblog/posts/pyplot-vs-object-oriented-interface/

# %% [markdown]
# ## Numeric Variables' Univariate Distribution

# %%
# Single Metric Variable Histogram
plt.hist(df["age"], bins=10)  # mess around with the bins
plt.title("age", y=-0.2)

plt.show()

# %%
# Single Metric Variable Box Plot
sns.boxplot(y=df["age"])

plt.show()

# %% [markdown]
# What information can we extract from the plot above?

# %%
# All Numeric Variables' Histograms in one figure
sns.set()

# Prepare figure. Create individual axes where each histogram will be placed
fig, axes = plt.subplots(2, ceil(len(metric_features) / 2), figsize=(20, 11))

# Plot data
# Iterate across axes objects and associate each histogram (hint: use the ax.hist() instead of plt.hist()):
for ax, feat in zip(axes.flatten(), metric_features): # Notice the zip() function and flatten() method
    # CODE HERE (extra: set each axis title as the feature name)
    
# Layout
# Add a centered title to the figure:
title = "Numeric Variables' Histograms"

plt.suptitle(title)

plt.show()

# %%
# All Numeric Variables' Box Plots in one figure
sns.set()

# Prepare figure. Create individual axes where each box plot will be placed
fig, axes = plt.subplots(2, ceil(len(metric_features) / 2), figsize=(20, 13))

# Plot data
# Iterate across axes objects and associate each box plot (hint: use the ax argument):
for ax, feat in zip(axes.flatten(), metric_features): # Notice the zip() function and flatten() method
    # CODE HERE
    
# Layout
# Add a centered title to the figure:
title = 'Numeric Variables\' Box Plots' # notice the "\"

# CODE HERE
plt.show()

# %% [markdown]
# ### Insights:
# - univariate distributions
# - potential univariate outliers
#
# --------------------------------------

# %% [markdown]
# ### During our Exploratory Data Analysis (EDA), we must also account for:
# - Coherence check
# - Outliers
# - Feature Engineering

# %% [markdown]
# ### Depending on the context, various steps must be considered when performing Data Preprocessing.
#
# The most relevant steps are the following:
# - Coherence check (find inconsistent values, missing values, outliers and any other problem you may find in your dataset)
# - Data editing (fix inconsistent values)
# - Data cleansing (drop observations - Outlier removal and removal of inconsistent values and/or features)
# - Data wrangling (feature extraction/engineering and transformation)
# - Data reduction (reducing the dimensionality of a dataset, producing summary statistics, reducing the number of records in a dataset)

# %% [markdown]
# ## Optional Exercise
#
# Download the [Amazing Internation Airlines Inc dataset](https://elearning.novaims.unl.pt/mod/folder/view.php?id=96622). Using the  `DM_AIAI_FlightsDB.csv
# ` and the `DM_AIAI_CustomerDB.csv`  file, perform the same exercises that we did in this notebook.
#
# Identify the metric and non-metric features in this dataset.
#
# Identify if any problems exist:
#
# - Duplicates?
# - Data types?
# - Missing values?
# - Strange values?
# - Descriptive statistics?

# %%
# please use pd.read_csv()
# try to note from if the separator is , or ; or \t
